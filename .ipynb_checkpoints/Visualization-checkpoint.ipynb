# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
donor_data = pd.read_csv('Donor Raw Data_ML with Python.csv')

# %%
prospective_donors = pd.read_csv('Prospective Donor_ML with Python.csv')

# %%
prospective_donors.shape
# Out:
# (2148, 48)

# %%
donor_data.isnull().sum()
# Out:
# TARGET_B                           0
# TARGET_D                       14529
# CONTROL_NUMBER                     0
# MONTHS_SINCE_ORIGIN                0
# DONOR_AGE                       4795
# IN_HOUSE                           0
# URBANICITY                         0
# SES                                0
# CLUSTER_CODE                       0
# HOME_OWNER                         0
# DONOR_GENDER                       0
# INCOME_GROUP                    4392
# PUBLISHED_PHONE                    0
# OVERLAY_SOURCE                     0
# MOR_HIT_RATE                       0
# WEALTH_RATING                   8810
# MEDIAN_HOME_VALUE                  0
# MEDIAN_HOUSEHOLD_INCOME            0
# PCT_OWNER_OCCUPIED                 0
# PER_CAPITA_INCOME                  0
# PCT_ATTRIBUTE1                     0
# PCT_ATTRIBUTE2                     0
# PCT_ATTRIBUTE3                     0
# PCT_ATTRIBUTE4                     0
# PEP_STAR                           0
# ...

# %%
figsize = (30,10)
sns.heatmap(donor_data.isnull(),yticklabels=False,cbar=False,cmap='viridis')
#Shows the missing data, columns that have missing data include Target_D, Donor_Age, Income group, wealth_rating, and months since last response

# %%
sns.heatmap(prospective_donors.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
donor_data.columns
# Out:
# Index(['TARGET_B', 'TARGET_D', 'CONTROL_NUMBER', 'MONTHS_SINCE_ORIGIN',
#        'DONOR_AGE', 'IN_HOUSE', 'URBANICITY', 'SES', 'CLUSTER_CODE',
#        'HOME_OWNER', 'DONOR_GENDER', 'INCOME_GROUP', 'PUBLISHED_PHONE',
#        'OVERLAY_SOURCE', 'MOR_HIT_RATE', 'WEALTH_RATING', 'MEDIAN_HOME_VALUE',
#        'MEDIAN_HOUSEHOLD_INCOME', 'PCT_OWNER_OCCUPIED', 'PER_CAPITA_INCOME',
#        'PCT_ATTRIBUTE1', 'PCT_ATTRIBUTE2', 'PCT_ATTRIBUTE3', 'PCT_ATTRIBUTE4',
#        'PEP_STAR', 'RECENT_STAR_STATUS', 'RECENCY_STATUS_96NK',
#        'FREQUENCY_STATUS_97NK', 'RECENT_RESPONSE_PROP', 'RECENT_AVG_GIFT_AMT',
#        'RECENT_CARD_RESPONSE_PROP', 'RECENT_AVG_CARD_GIFT_AMT',
#        'RECENT_RESPONSE_COUNT', 'RECENT_CARD_RESPONSE_COUNT',
#        'MONTHS_SINCE_LAST_PROM_RESP', 'LIFETIME_CARD_PROM', 'LIFETIME_PROM',
#        'LIFETIME_GIFT_AMOUNT', 'LIFETIME_GIFT_COUNT', 'LIFETIME_AVG_GIFT_AMT',
#        'LIFETIME_GIFT_RANGE', 'LIFETIME_MAX_GIFT_AMT', 'LIFETIME_MIN_GIFT_AMT',
# ...

# %%
sns.set_style('whitegrid')
sns.countplot(x='TARGET_B', data = donor_data)

# %%
#check if the columns in the training and testing data match
col_train = list(donor_data.columns)
col_test = list(prospective_donors.columns)
[values for values in col_train if values not in col_test]
# Out:
# ['TARGET_B', 'TARGET_D']

# %%
#Print percentage of null value per group

for cols in donor_data.columns:
    if donor_data[cols].isna().sum()!=0:
        print('percentage null', cols, 'is:', ((donor_data[cols].isna().sum())/len(donor_data))*100, 'percent')
# Out:
# percentage null TARGET_D is: 75.0 percent
# percentage null DONOR_AGE is: 24.752219698533967 percent
# percentage null INCOME_GROUP is: 22.671897584142062 percent
# percentage null WEALTH_RATING is: 45.47800949824489 percent
# percentage null MONTHS_SINCE_LAST_PROM_RESP is: 1.2698740450134214 percent

# %%
donor_data.describe()
# Out:
#            TARGET_B     TARGET_D  CONTROL_NUMBER  MONTHS_SINCE_ORIGIN  \
# count  19372.000000  4843.000000    19372.000000         19372.000000
# mean       0.250000    15.624344    96546.225377            73.409973
# std        0.433024    12.445137    55830.643871            41.255574
# min        0.000000     1.000000        5.000000             5.000000
# 25%        0.000000    10.000000    48289.000000            29.000000
# 50%        0.000000    13.000000    96937.000000            65.000000
# 75%        0.250000    20.000000   145429.500000           113.000000
# max        1.000000   200.000000   191779.000000           137.000000
#
#           DONOR_AGE      IN_HOUSE  INCOME_GROUP  PUBLISHED_PHONE  \
# count  14577.000000  19372.000000  14980.000000     19372.000000
# mean      58.919051      0.073198      3.907543         0.497729
# std       16.669382      0.260469      1.864796         0.500008
# min        0.000000      0.000000      1.000000         0.000000
# ...

# %%
donor_data[donor_data['DONOR_AGE']==0]
# Out:
#        TARGET_B  TARGET_D  CONTROL_NUMBER  MONTHS_SINCE_ORIGIN  DONOR_AGE  \
# 8967          0       NaN           89765                   77        0.0
# 13698         0       NaN          137263                  137        0.0
#
#        IN_HOUSE URBANICITY SES CLUSTER_CODE HOME_OWNER  ...  \
# 8967          0          S   2           20          U  ...
# 13698         0          C   1           23          H  ...
#
#       LIFETIME_GIFT_RANGE  LIFETIME_MAX_GIFT_AMT  LIFETIME_MIN_GIFT_AMT  \
# 8967                 13.0                   18.0                    5.0
# 13698                32.0                   37.0                    5.0
#
#       LAST_GIFT_AMT  CARD_PROM_12  NUMBER_PROM_12  MONTHS_SINCE_LAST_GIFT  \
# 8967           14.0             6              13                      21
# 13698          37.0             6              14                      18
#
#        MONTHS_SINCE_FIRST_GIFT  FILE_AVG_GIFT  FILE_CARD_GIFT
# ...

# %%
corr_matrix = donor_data.corr()
corr_matrix['TARGET_B'].sort_values(ascending = True)
# Out:
# MONTHS_SINCE_LAST_GIFT        -0.089854
# RECENT_AVG_GIFT_AMT           -0.074668
# LAST_GIFT_AMT                 -0.068220
# LIFETIME_AVG_GIFT_AMT         -0.067107
# FILE_AVG_GIFT                 -0.067107
# MONTHS_SINCE_LAST_PROM_RESP   -0.066744
# LIFETIME_MIN_GIFT_AMT         -0.062756
# LIFETIME_MAX_GIFT_AMT         -0.036990
# RECENT_AVG_CARD_GIFT_AMT      -0.016935
# PCT_ATTRIBUTE3                -0.010106
# LIFETIME_GIFT_RANGE           -0.006354
# PCT_ATTRIBUTE1                -0.003648
# PUBLISHED_PHONE               -0.003219
# RECENT_STAR_STATUS            -0.001475
# PCT_ATTRIBUTE2                 0.008815
# PCT_ATTRIBUTE4                 0.010067
# MOR_HIT_RATE                   0.012689
# PCT_OWNER_OCCUPIED             0.015720
# CONTROL_NUMBER                 0.024607
# WEALTH_RATING                  0.034742
# DONOR_AGE                      0.036949
# MEDIAN_HOUSEHOLD_INCOME        0.038190
# CARD_PROM_12                   0.038947
# ...

# %%
givers = donor_data[donor_data['TARGET_B']==1]

# %%
sns.countplot(donor_data['WEALTH_RATING'])
plt.title('General wealth rating distribution')
# Out:
# Text(0.5, 1.0, 'General wealth rating distribution')

# %%
sns.countplot(givers['WEALTH_RATING'])
plt.title('Wealth rating distribution among donors')
# Out:
# Text(0.5, 1.0, 'Wealth rating distribution among donors')

# %%
sns.countplot(donor_data['INCOME_GROUP'])
plt.title('General income group distribution')
# Out:
# Text(0.5, 1.0, 'General income group distribution')

# %%
sns.countplot(givers['INCOME_GROUP'])
plt.title('Income group distribution among givers')
# Out:
# Text(0.5, 1.0, 'Income group distribution among givers')

# %%
donor_data['RECENT_RESPONSE_COUNT'].unique()
# Out:
# array([ 1,  4,  9,  2,  3,  8,  5, 11,  7, 12, 10,  6,  0, 13, 15, 14, 16],
#       dtype=int64)

# %%
sns.countplot(data = donor_data, x = 'TARGET_B', hue = 'FREQUENCY_STATUS_97NK')

# %%
sns.boxplot(data = donor_data, x = 'TARGET_B', y = 'RECENT_RESPONSE_COUNT')

# %%
sns.boxplot(data = donor_data, x = 'TARGET_B', y = 'RECENT_CARD_RESPONSE_COUNT')

# %%
sns.boxplot(data = donor_data, x = 'TARGET_B', y = 'FILE_CARD_GIFT')

# %%
sns.countplot(data = donor_data_clean, x = 'TARGET_B', hue = 'SES')

# %%
sns.countplot(data = donor_data_clean, x = 'TARGET_B', hue = 'IN_HOUSE')

# %%
sns.countplot(data = donor_data, x = 'URBANICITY')

# %%
sns.countplot(data = donor_data, x = 'TARGET_B',hue = 'URBANICITY')

# %%
len(donor_data[donor_data['DONOR_GENDER']=='F'][donor_data['TARGET_B']==1])/len(donor_data[donor_data['DONOR_GENDER']=='F'])
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 0.25084126526295547

# %%
sns.countplot(data = donor_data_clean, x = 'TARGET_B', hue = 'DONOR_GENDER')

# %%
sns.countplot(data = donor_data_clean, x = 'TARGET_B', hue = 'HOME_OWNER')

# %%
sns.boxplot(data = donor_data, x = 'TARGET_B', y = 'MONTHS_SINCE_ORIGIN')

# %%
donor_data_clean.loc[:,'RECENT_AVG_CARD_GIFT_AMT':]
# Out:
#        RECENT_AVG_CARD_GIFT_AMT  RECENT_RESPONSE_COUNT  \
# 0                          0.00                      1
# 1                         15.00                      4
# 2                         22.67                      9
# 3                         13.50                      9
# 4                         10.00                      2
# ...                         ...                    ...
# 19366                      5.00                      4
# 19367                     15.00                      2
# 19368                     10.00                      4
# 19370                      0.00                      1
# 19371                     25.00                      1
#
#        MONTHS_SINCE_LAST_PROM_RESP  LIFETIME_PROM  LIFETIME_GIFT_AMOUNT  \
# 0                             26.0             45                 297.0
# 1                             11.0             90                 368.0
# 2                             14.0            119                 603.0
# ...

# %%
sns.countplot(data = donor_data_clean, x = 'TARGET_B',hue = 'PUBLISHED_PHONE')

# %%
sns.countplot(data = donor_data_clean, x = 'TARGET_B',hue = 'OVERLAY_SOURCE')

# %%
sns.scatterplot(data = donor_data, x = 'MOR_HIT_RATE', y = 'MEDIAN_HOME_VALUE', hue = 'TARGET_B')

# %%
sns.boxplot(data = donor_data[donor_data['MOR_HIT_RATE']<10], x = 'TARGET_B', y = 'MOR_HIT_RATE')

# %%
sns.boxplot(data = donor_data, x = 'TARGET_B', y = 'MEDIAN_HOME_VALUE')

# %%
sns.boxplot(data = donor_data, x = 'TARGET_B', y = 'PCT_OWNER_OCCUPIED')

# %%
sns.boxplot(data = donor_data, x = 'TARGET_B', y = 'PER_CAPITA_INCOME')

# %%
sns.countplot(data = donor_data_clean, x = 'TARGET_B',hue = 'RECENCY_STATUS_96NK')
